# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
#from sklearn.cross_validation import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Nicky\\Desktop\\my work\\case study'

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('training/training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("training/training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    #print("column",column)
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 292.82451503107393 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sortlevel()
test_class_distribution = test_df['Class'].value_counts().sortlevel()
cv_class_distribution = cv_df['Class'].value_counts().sortlevel()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.5805813801201625
# Log loss on Test Data using Random Model 2.5314000095004414
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 232
# BRCA1     180
# TP53      101
# EGFR       91
# BRCA2      80
# PTEN       76
# BRAF       62
# KIT        59
# ALK        48
# ERBB2      44
# PDGFRA     37
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 232 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
# %time train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
# %time test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
# %time cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))
# Out:
# Wall time: 8.46 s
# Wall time: 4.44 s
# Wall time: 4.09 s

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = TfidfVectorizer(max_features=1000)
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 652     CDKN2A
# 409       TP53
# 1601       VHL
# 3205       RB1
# 1221    PIK3CB
# Name: Gene, dtype: object

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 232)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.4098471323615982
# For values of alpha =  0.0001 The log loss is: 1.2186914103485624
# For values of alpha =  0.001 The log loss is: 1.204697021800755
# For values of alpha =  0.01 The log loss is: 1.3013524433956978
# For values of alpha =  0.1 The log loss is: 1.4290311938356566
# For values of alpha =  1 The log loss is: 1.4750726316787446
# For values of best alpha =  0.001 The train log loss is: 1.109305441896034
# For values of best alpha =  0.001 The cross validation log loss is: 1.204697021800755
# For values of best alpha =  0.001 The test log loss is: 1.225667392825366

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  232  genes in train dataset?
# Ans
# 1. In test data 646 out of 665 : 97.14285714285714
# 2. In cross validation data 512 out of  532 : 96.2406015037594

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1924
# Deletion                54
# Truncating_Mutations    52
# Amplification           49
# Fusions                 23
# Overexpression           5
# Q61H                     3
# ETV6-NTRK3_Fusion        2
# F28L                     2
# E17K                     2
# Q61R                     2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1924 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.02542373 0.05084746 0.07297552 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
# %time train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
# %time test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
# %time cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))
# Out:
# Wall time: 1min 9s
# Wall time: 36.9 s
# Wall time: 34 s

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = TfidfVectorizer(max_features=1000,ngram_range=(1,2))
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 1000)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.7138509607956236
# For values of alpha =  0.0001 The log loss is: 1.7014762937358459
# For values of alpha =  0.001 The log loss is: 1.703970068377221
# For values of alpha =  0.01 The log loss is: 1.7155000275814147
# For values of alpha =  0.1 The log loss is: 1.7311692422350762
# For values of alpha =  1 The log loss is: 1.7329588779348637
# For values of best alpha =  0.0001 The train log loss is: 1.1985514029680788
# For values of best alpha =  0.0001 The cross validation log loss is: 1.7014762937358459
# For values of best alpha =  0.0001 The test log loss is: 1.7154793113242284

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1924  genes in test and cross validation data sets?
# Ans
# 1. In test data 67 out of 665 : 10.075187969924812
# 2. In cross validation data 51 out of  532 : 9.586466165413533

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
train_df['TEXT'].head()
# Out:
# 652     inherited mutations affecting ink4a arf locus ...
# 409     p53 protein transcription factor involved mult...
# 1601    von hippel lindau tumor suppressor protein pvh...
# 3205    tumor suppressor prb plays key role regulating...
# 1221    pik3ca gene encoding p110 subunit class ia pho...
# Name: TEXT, dtype: object

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = TfidfVectorizer(max_features=1000,min_df=3)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])

#train_text_features = top_mean_feats(train_text_feature_onehotCoding,
                                               # text_vectorizer.get_feature_names())['feature'].tolist()
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 1000

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({250.00608040254912: 1, 180.22137806956025: 1, 142.44308141067313: 1, 131.63284242157576: 1, 129.04059291612063: 1, 117.51171694902142: 1, 117.00609052715429: 1, 113.25209431558261: 1, 108.64275850933033: 1, 108.37911956395023: 1, 107.50222375882093: 1, 88.64514406460698: 1, 87.7658993131776: 1, 83.42072848560562: 1, 81.66422136644373: 1, 79.42994864633863: 1, 77.71962292454867: 1, 77.71321595867487: 1, 77.0473719602032: 1, 76.2096032087765: 1, 75.11039981737645: 1, 74.2501904764289: 1, 70.12073605393779: 1, 69.15008197928846: 1, 66.63678198803933: 1, 65.14200864213507: 1, 64.89958309172015: 1, 64.3089383124547: 1, 63.56241320437786: 1, 63.023660087716756: 1, 62.88862822808212: 1, 62.515763116225536: 1, 61.69417188097203: 1, 59.57776758106238: 1, 58.68892465066138: 1, 58.227169382053056: 1, 55.94058246093612: 1, 55.40060885728273: 1, 54.49433313822408: 1, 53.48350243038154: 1, 51.335628807275185: 1, 51.23413095186216: 1, 51.021430347754844: 1, 48.57652590196454: 1, 48.15899266985451: 1, 46.19346028903731: 1, 45.36421396642371: 1, 44.91248200645347: 1, 44.72389091299477: 1, 43.87415440463058: 1, 43.61783158193181: 1, 43.37901448571501: 1, 43.15212765189394: 1, 42.86435050746076: 1, 42.76194080217711: 1, 42.34739961440966: 1, 42.04817517422137: 1, 42.04274079713571: 1, 41.63608343837715: 1, 41.40790266377587: 1, 41.28607819247059: 1, 40.89614467961131: 1, 40.78828674818691: 1, 40.6269229124476: 1, 40.55348951049605: 1, 39.48155442323011: 1, 39.129927362009084: 1, 38.57091701565032: 1, 38.44415419668068: 1, 38.34457880009: 1, 38.174064919118535: 1, 38.10222551629687: 1, 37.94031833697888: 1, 37.2450860010055: 1, 37.09408516219819: 1, 36.285248122946214: 1, 36.07079910532971: 1, 36.0463928178859: 1, 35.551309914191414: 1, 35.54227881445707: 1, 35.41501790325633: 1, 35.11561638803439: 1, 34.762731399659806: 1, 34.622159101527025: 1, 34.613901745108535: 1, 34.60494431794907: 1, 34.22466801453331: 1, 33.85407890394386: 1, 33.5381586472954: 1, 32.989760190600684: 1, 32.88470002983171: 1, 32.849106894765384: 1, 32.60518140431479: 1, 32.53040285561305: 1, 32.49441970394909: 1, 32.31788493138674: 1, 32.27544306686532: 1, 32.09163478039667: 1, 32.0303974060314: 1, 31.972258686172385: 1, 31.890046771830768: 1, 31.78117729363846: 1, 31.742142235458903: 1, 31.599249951795503: 1, 31.451744643365412: 1, 31.02419800667444: 1, 31.01997578688599: 1, 30.796063043629058: 1, 30.760328226792144: 1, 30.704995583190062: 1, 30.678089895357278: 1, 30.661831545687264: 1, 30.6265989815602: 1, 30.593558050720052: 1, 30.550993713475886: 1, 30.421768703341915: 1, 30.36592758511303: 1, 30.11830160788303: 1, 29.628926774785473: 1, 29.579999657603306: 1, 29.492262975443673: 1, 29.352352807110673: 1, 29.10458354835115: 1, 29.081581965746693: 1, 28.986199859936537: 1, 28.824870424781107: 1, 28.605240658533056: 1, 28.472004051407644: 1, 28.45613445979494: 1, 28.294648059584194: 1, 28.088595366637836: 1, 27.954139040106714: 1, 27.759671275109326: 1, 27.578503998911156: 1, 27.56667637993015: 1, 27.50343674025393: 1, 27.406138706883667: 1, 27.317626009481337: 1, 27.089895589515812: 1, 27.001148305750636: 1, 26.97372655184015: 1, 26.918778489092006: 1, 26.6037120732849: 1, 26.4392466304859: 1, 26.399773768508844: 1, 26.30744348392509: 1, 26.245498526181695: 1, 26.045075408353227: 1, 25.964427301093114: 1, 25.81008589393176: 1, 25.786168470297607: 1, 25.664366165140013: 1, 25.64731297857759: 1, 25.424704706933763: 1, 25.397213565691228: 1, 25.28748935150129: 1, 25.049269057300844: 1, 25.018710605988982: 1, 24.835557849122036: 1, 24.782852951727353: 1, 24.34414024405833: 1, 24.313963990441543: 1, 24.290563886405614: 1, 23.960264607785618: 1, 23.809435487540178: 1, 23.78986071974865: 1, 23.7810013610832: 1, 23.77873029503457: 1, 23.710018482548467: 1, 23.702239141472305: 1, 23.69163701461788: 1, 23.654655392650223: 1, 23.605144870295135: 1, 23.551296899720835: 1, 23.484821541090216: 1, 23.4584651179228: 1, 23.39094424482289: 1, 23.269776760634592: 1, 23.2570807155 ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.0990548440386911
# For values of alpha =  0.0001 The log loss is: 1.0931883702730918
# For values of alpha =  0.001 The log loss is: 1.405061936340565
# For values of alpha =  0.01 The log loss is: 1.9348530127906534
# For values of alpha =  0.1 The log loss is: 2.0573312989301438
# For values of alpha =  1 The log loss is: 2.044099797781195
# For values of best alpha =  0.0001 The train log loss is: 0.8354855055258321
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0931883702730918
# For values of best alpha =  0.0001 The test log loss is: 1.126190628951383

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = TfidfVectorizer(max_features=1000,min_df=3)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 95.0 % of word of test data appeared in train data
# 93.9 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer(max_features=1000)
    var_count_vec = TfidfVectorizer(max_features=1000)
    text_count_vec = TfidfVectorizer(min_df=3,max_features=1000)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 2232)
# (number of data points * number of features) in test data =  (665, 2232)
# (number of data points * number of features) in cross validation data = (532, 2232)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.137186311390725
# for alpha = 0.0001
# Log Loss : 1.1372699587433164
# for alpha = 0.001
# Log Loss : 1.1374457716188013
# for alpha = 0.1
# Log Loss : 1.1328464527238877
# for alpha = 1
# Log Loss : 1.193048005256218
# for alpha = 10
# Log Loss : 1.3599494083440171
# for alpha = 100
# Log Loss : 1.3797896051227365
# for alpha = 1000
# Log Loss : 1.3802781193790168
# For values of best alpha =  0.1 The train log loss is: 0.7964739415475441
# For values of best alpha =  0.1 The cross validation log loss is: 1.1328464527238877
# For values of best alpha =  0.1 The test log loss is: 1.1897907369999863

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.1328464527238877
# Number of missclassified point : 0.36654135338345867
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 25
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0686 0.0445 0.0156 0.7439 0.0353 0.033  0.0501 0.0043 0.0046]]
# Actual Class : 4
# --------------------------------------------------
# 13 Text feature [activity] present in test data point [True]
# 15 Text feature [protein] present in test data point [True]
# 16 Text feature [proteins] present in test data point [True]
# 17 Text feature [function] present in test data point [True]
# 18 Text feature [missense] present in test data point [True]
# 19 Text feature [results] present in test data point [True]
# 20 Text feature [acid] present in test data point [True]
# 21 Text feature [amino] present in test data point [True]
# 23 Text feature [experiments] present in test data point [True]
# Out of the top  25  features  9 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 25
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0986 0.0603 0.0184 0.4684 0.0426 0.0398 0.2613 0.0051 0.0055]]
# Actual Class : 7
# --------------------------------------------------
# 13 Text feature [activity] present in test data point [True]
# 15 Text feature [protein] present in test data point [True]
# 16 Text feature [proteins] present in test data point [True]
# 17 Text feature [function] present in test data point [True]
# 19 Text feature [results] present in test data point [True]
# 23 Text feature [experiments] present in test data point [True]
# Out of the top  25  features  6 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.0274330250018986
# for alpha = 11
# Log Loss : 0.9863047490333859
# for alpha = 15
# Log Loss : 0.9985699947114779
# for alpha = 21
# Log Loss : 1.0277936210990835
# for alpha = 31
# Log Loss : 1.0470777811862657
# for alpha = 41
# Log Loss : 1.0625187589451517
# for alpha = 51
# Log Loss : 1.0729893463026223
# for alpha = 99
# Log Loss : 1.0654414608321998
# For values of best alpha =  11 The train log loss is: 0.643438926678461
# For values of best alpha =  11 The cross validation log loss is: 0.9863047490333859
# For values of best alpha =  11 The test log loss is: 1.0833768744633592

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 0.9863047490333859
# Number of mis-classified points : 0.35526315789473684
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 4
# Actual Class : 4
# The  11  nearest neighbours of the test points belongs to classes [4 4 4 4 4 4 4 4 4 4 4]
# Fequency of nearest points : Counter({4: 11})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# the k value for knn is 11 and the nearest neighbours of the test points belongs to classes [7 7 7 7 7 7 7 7 7 1 7]
# Fequency of nearest points : Counter({7: 10, 1: 1})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1319013424526188
# for alpha = 1e-05
# Log Loss : 1.0853870738061007
# for alpha = 0.0001
# Log Loss : 0.9815936100693827
# for alpha = 0.001
# Log Loss : 1.0024593935335802
# for alpha = 0.01
# Log Loss : 1.1638798260470324
# for alpha = 0.1
# Log Loss : 1.6404073552870004
# for alpha = 1
# Log Loss : 1.797070471215017
# for alpha = 10
# Log Loss : 1.8142971103481205
# for alpha = 100
# Log Loss : 1.8161292422287096
# For values of best alpha =  0.0001 The train log loss is: 0.5856433700854058
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9815936100693827
# For values of best alpha =  0.0001 The test log loss is: 1.02910021905037

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9815936100693827
# Number of mis-classified points : 0.32894736842105265
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0379 0.0578 0.0153 0.7553 0.0241 0.0135 0.0823 0.0045 0.0094]]
# Actual Class : 4
# --------------------------------------------------
# 65 Text feature [missense] present in test data point [True]
# 81 Text feature [high] present in test data point [True]
# 88 Text feature [mm] present in test data point [True]
# 92 Text feature [show] present in test data point [True]
# 96 Text feature [dominant] present in test data point [True]
# 100 Text feature [changes] present in test data point [True]
# 104 Text feature [transfected] present in test data point [True]
# 110 Text feature [process] present in test data point [True]
# 112 Text feature [low] present in test data point [True]
# 128 Text feature [protein] present in test data point [True]
# 148 Text feature [caused] present in test data point [True]
# 156 Text feature [deletion] present in test data point [True]
# 157 Text feature [degradation] present in test data point [True]
# 161 Text feature [suggesting] present in test data point [True]
# 178 Text feature [induced] present in test data point [True]
# 181 Text feature [antibodies] present in test data point [True]
# 182 Text feature [tagged] present in test data point [True]
# 187 Text feature [heterozygous] present in test data point [True]
# 188 Text feature [mice] present in test data point [True]
# 192 Text feature [lane] present in test data point [True]
# 205 Text feature [express] present in test data point [True]
# 207 Text feature [null] present in test data point [True]
# 213 Text feature [family] present in test data point [True]
# 217 Text feature [recognition] present in test data point [True]
# 219 Text feature [indicate] present in test data point [True]
# 225 Text feature [stability] present in test data point [True]
# 228 Text feature [proteins] present in test data point [True]
# 234 Text feature [due] present in test data point [True]
# 239 Text feature [decreased] present in test data point [True]
# 245 Text feature [motif] present in test data point [True]
# 246 Text feature [primary] present in test data point [True]
# 250 Text feature [washed] present in test data point [True]
# 263 Text feature [loss] present in test data point [True]
# 271 Text feature [provided] present in test data point [True]
# 282 Text feature [interact] present in test data point [True]
# 285 Text feature [endogenous] present in test data point [True]
# 289 Text feature [substrate] present in test data point [True]
# 292 Text feature [lines] present in test data point [True]
# 296 Text feature [26] present in test data point [True]
# 303 Text feature [4a] present in test data point [True]
# 308 Text feature [29] present in test data point [True]
# 310 Text feature [described] present in test data point [True]
# 313 Text feature [1b] present in test data point [True]
# 316 Text feature [regions] present in test data point [True]
# 317 Text feature [supplementary] present in test data point [True]
# 319 Text feature [cases] present in test data point [True]
# 322 Text feature [activity] present in test data point [True]
# 326 Text feature [staining] present in test data point [True]
# 327 Text feature [reporter] present in test data point [True]
# 329 Text feature [mutants] present in test data point [True]
# 334 Text feature [12] present in test data point [True]
# 341 Text feature [red] present in test data point [True]
# 342 Text feature [several] present in test data point [True]
# 346 Text feature [specifically] present in test data point [True]
# 348 Text feature [elevated] present in test data point [True]
# 353 Text feature [plates] present in test data point [True]
# 362 Text feature [alterations] present in test data point [True]
# 368 Text feature [antibody] present in test data point [True]
# 369 Text feature [blue] present in test data point [True]
# 384 Text feature [lower] present in test data point [True]
# 385 Text feature [normal] present in test data point [True]
# 387 Text feature [affected] present in test data point [True]
# 391 Text feature [pattern] present in test data point [True]
# 392 Text feature [according] present in test data point [True]
# 403 Text feature [rna] present in test data point [True]
# 404 Text feature [keap1] present in test data point [True]
# 405 Text feature [reduced] present in test data point [True]
# 413 Text feature [transfection] present in test data point [True]
# 415 Text feature [contribute] present in test data point [True]
# 417 Text feature [among] present in test data point [True]
# 418 Text feature [dna] present in test data point [True]
# 426 Text feature [suggest] present in test data point [True]
# 427 Text feature [3b] present in test data point [True]
# 429 Text feature [complex] present in test data point [True]
# 430 Text feature [double] present in test data point [True]
# 433 Text feature [determine] present in test data point [True]
# 438 Text feature [hours] present in test data point [True]
# 448 Text feature [cause] present in test data point [True]
# 454 Text feature [various] present in test data point [True]
# 455 Text feature [flag] present in test data point [True]
# 459 Text feature [observed] present in test data point [True]
# 460 Text feature [isolated] present in test data point [True]
# 461 Text feature [analysis] present in test data point [True]
# 462 Text feature [detected] present in test data point [True]
# 463 Text feature [containing] present in test data point [True]
# 464 Text feature [function] present in test data point [True]
# 468 Text feature [least] present in test data point [True]
# 470 Text feature [locus] present in test data point [True]
# 474 Text feature [role] present in test data point [True]
# 476 Text feature [nih] present in test data point [True]
# 481 Text feature [bind] present in test data point [True]
# 483 Text feature [plasmid] present in test data point [True]
# 484 Text feature [rate] present in test data point [True]
# 492 Text feature [tissues] present in test data point [True]
# 493 Text feature [amino] present in test data point [True]
# 496 Text feature [american] present in test data point [True]
# Out of the top  500  features  96 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. correctly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[5.350e-02 2.480e-02 5.000e-04 1.556e-01 7.500e-03 3.300e-03 7.453e-01
#   9.200e-03 4.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 4 Text feature [insertion] present in test data point [True]
# 6 Text feature [downstream] present in test data point [True]
# 9 Text feature [activation] present in test data point [True]
# 15 Text feature [overexpression] present in test data point [True]
# 19 Text feature [transformed] present in test data point [True]
# 20 Text feature [activate] present in test data point [True]
# 24 Text feature [activated] present in test data point [True]
# 25 Text feature [enhanced] present in test data point [True]
# 28 Text feature [oncogene] present in test data point [True]
# 30 Text feature [gists] present in test data point [True]
# 31 Text feature [oncogenic] present in test data point [True]
# 34 Text feature [pathways] present in test data point [True]
# 35 Text feature [2a] present in test data point [True]
# 38 Text feature [inhibited] present in test data point [True]
# 41 Text feature [expressing] present in test data point [True]
# 51 Text feature [lung] present in test data point [True]
# 53 Text feature [promote] present in test data point [True]
# 55 Text feature [mechanisms] present in test data point [True]
# 59 Text feature [bone] present in test data point [True]
# 64 Text feature [constitutive] present in test data point [True]
# 66 Text feature [approximately] present in test data point [True]
# 74 Text feature [ras] present in test data point [True]
# 76 Text feature [factor] present in test data point [True]
# 78 Text feature [transformation] present in test data point [True]
# 82 Text feature [her2] present in test data point [True]
# 87 Text feature [signaling] present in test data point [True]
# 89 Text feature [s3] present in test data point [True]
# 90 Text feature [somatic] present in test data point [True]
# 99 Text feature [bp] present in test data point [True]
# 102 Text feature [3b] present in test data point [True]
# 103 Text feature [ligand] present in test data point [True]
# 106 Text feature [form] present in test data point [True]
# 119 Text feature [long] present in test data point [True]
# 126 Text feature [additional] present in test data point [True]
# 127 Text feature [leading] present in test data point [True]
# 140 Text feature [fold] present in test data point [True]
# 144 Text feature [positive] present in test data point [True]
# 145 Text feature [demonstrated] present in test data point [True]
# 161 Text feature [adenocarcinoma] present in test data point [True]
# 171 Text feature [24] present in test data point [True]
# 173 Text feature [2b] present in test data point [True]
# 175 Text feature [mapk] present in test data point [True]
# 181 Text feature [factors] present in test data point [True]
# 187 Text feature [regulated] present in test data point [True]
# 192 Text feature [advanced] present in test data point [True]
# 195 Text feature [epithelial] present in test data point [True]
# 203 Text feature [genomic] present in test data point [True]
# 205 Text feature [contrast] present in test data point [True]
# 212 Text feature [higher] present in test data point [True]
# 216 Text feature [signals] present in test data point [True]
# 221 Text feature [derived] present in test data point [True]
# 227 Text feature [lead] present in test data point [True]
# 229 Text feature [nucleotide] present in test data point [True]
# 233 Text feature [basal] present in test data point [True]
# 237 Text feature [found] present in test data point [True]
# 253 Text feature [catenin] present in test data point [True]
# 259 Text feature [contribute] present in test data point [True]
# 260 Text feature [increased] present in test data point [True]
# 262 Text feature [coding] present in test data point [True]
# 264 Text feature [elevated] present in test data point [True]
# 265 Text feature [caused] present in test data point [True]
# 267 Text feature [presence] present in test data point [True]
# 268 Text feature [days] present in test data point [True]
# 272 Text feature [72] present in test data point [True]
# 279 Text feature [fig] present in test data point [True]
# 282 Text feature [occur] present in test data point [True]
# 286 Text feature [position] present in test data point [True]
# 287 Text feature [domain] present in test data point [True]
# 294 Text feature [pathway] present in test data point [True]
# 301 Text feature [inhibition] present in test data point [True]
# 303 Text feature [mechanism] present in test data point [True]
# 308 Text feature [egf] present in test data point [True]
# 314 Text feature [000] present in test data point [True]
# 315 Text feature [61] present in test data point [True]
# 318 Text feature [cancers] present in test data point [True]
# 322 Text feature [size] present in test data point [True]
# 326 Text feature [malignant] present in test data point [True]
# 329 Text feature [high] present in test data point [True]
# 330 Text feature [less] present in test data point [True]
# 331 Text feature [increase] present in test data point [True]
# 333 Text feature [total] present in test data point [True]
# 337 Text feature [example] present in test data point [True]
# 338 Text feature [leads] present in test data point [True]
# 339 Text feature [gain] present in test data point [True]
# 343 Text feature [open] present in test data point [True]
# 344 Text feature [amplification] present in test data point [True]
# 346 Text feature [3a] present in test data point [True]
# 348 Text feature [blood] present in test data point [True]
# 351 Text feature [four] present in test data point [True]
# 357 Text feature [absence] present in test data point [True]
# 359 Text feature [tumors] present in test data point [True]
# 361 Text feature [37] present in test data point [True]
# 365 Text feature [4a] present in test data point [True]
# 368 Text feature [taken] present in test data point [True]
# 369 Text feature [raf] present in test data point [True]
# 370 Text feature [vector] present in test data point [True]
# 371 Text feature [survival] present in test data point [True]
# 372 Text feature [together] present in test data point [True]
# 375 Text feature [regions] present in test data point [True]
# 387 Text feature [examined] present in test data point [True]
# 394 Text feature [transcription] present in test data point [True]
# 399 Text feature [double] present in test data point [True]
# 400 Text feature [addition] present in test data point [True]
# 408 Text feature [right] present in test data point [True]
# 410 Text feature [stem] present in test data point [True]
# 411 Text feature [32] present in test data point [True]
# 412 Text feature [reverse] present in test data point [True]
# 413 Text feature [per] present in test data point [True]
# 414 Text feature [leukemia] present in test data point [True]
# 416 Text feature [75] present in test data point [True]
# 418 Text feature [mutated] present in test data point [True]
# 419 Text feature [interestingly] present in test data point [True]
# 421 Text feature [provided] present in test data point [True]
# 423 Text feature [indicating] present in test data point [True]
# 432 Text feature [obtained] present in test data point [True]
# 434 Text feature [prior] present in test data point [True]
# 436 Text feature [44] present in test data point [True]
# 440 Text feature [subsequent] present in test data point [True]
# 444 Text feature [note] present in test data point [True]
# 447 Text feature [signalling] present in test data point [True]
# 455 Text feature [52] present in test data point [True]
# 457 Text feature [showed] present in test data point [True]
# 458 Text feature [sirna] present in test data point [True]
# 459 Text feature [strong] present in test data point [True]
# 462 Text feature [suggest] present in test data point [True]
# 464 Text feature [fact] present in test data point [True]
# 465 Text feature [effective] present in test data point [True]
# 466 Text feature [previously] present in test data point [True]
# 468 Text feature [distinct] present in test data point [True]
# 469 Text feature [driven] present in test data point [True]
# 475 Text feature [primers] present in test data point [True]
# 477 Text feature [activating] present in test data point [True]
# 478 Text feature [box] present in test data point [True]
# 479 Text feature [sites] present in test data point [True]
# 480 Text feature [patient] present in test data point [True]
# 482 Text feature [normal] present in test data point [True]
# 484 Text feature [specimens] present in test data point [True]
# 488 Text feature [1a] present in test data point [True]
# 490 Text feature [region] present in test data point [True]
# 491 Text feature [common] present in test data point [True]
# 498 Text feature [29] present in test data point [True]
# 499 Text feature [level] present in test data point [True]
# Out of the top  500  features  142 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1028257763206673
# for alpha = 1e-05
# Log Loss : 1.1014620450424442
# for alpha = 0.0001
# Log Loss : 1.0043707595235494
# for alpha = 0.001
# Log Loss : 1.0720367727755875
# for alpha = 0.01
# Log Loss : 1.3643079466399801
# for alpha = 0.1
# Log Loss : 1.7069403480260021
# for alpha = 1
# Log Loss : 1.8071146178399335
# For values of best alpha =  0.0001 The train log loss is: 0.5729252899547868
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0043707595235494
# For values of best alpha =  0.0001 The test log loss is: 1.0476694515932696

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0043707595235494
# Number of mis-classified points : 0.32706766917293234
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0384 0.0611 0.0144 0.7559 0.0254 0.0138 0.0769 0.0046 0.0096]]
# Actual Class : 4
# --------------------------------------------------
# 65 Text feature [missense] present in test data point [True]
# 67 Text feature [high] present in test data point [True]
# 84 Text feature [show] present in test data point [True]
# 90 Text feature [changes] present in test data point [True]
# 99 Text feature [low] present in test data point [True]
# 100 Text feature [process] present in test data point [True]
# 104 Text feature [protein] present in test data point [True]
# 112 Text feature [dominant] present in test data point [True]
# 124 Text feature [mm] present in test data point [True]
# 125 Text feature [express] present in test data point [True]
# 140 Text feature [deletion] present in test data point [True]
# 141 Text feature [suggesting] present in test data point [True]
# 142 Text feature [transfected] present in test data point [True]
# 143 Text feature [induced] present in test data point [True]
# 165 Text feature [mice] present in test data point [True]
# 167 Text feature [washed] present in test data point [True]
# 170 Text feature [caused] present in test data point [True]
# 175 Text feature [degradation] present in test data point [True]
# 185 Text feature [endogenous] present in test data point [True]
# 193 Text feature [antibodies] present in test data point [True]
# 195 Text feature [family] present in test data point [True]
# 198 Text feature [heterozygous] present in test data point [True]
# 203 Text feature [tagged] present in test data point [True]
# 209 Text feature [null] present in test data point [True]
# 213 Text feature [due] present in test data point [True]
# 220 Text feature [decreased] present in test data point [True]
# 222 Text feature [proteins] present in test data point [True]
# 227 Text feature [indicate] present in test data point [True]
# 229 Text feature [primary] present in test data point [True]
# 233 Text feature [provided] present in test data point [True]
# 235 Text feature [lines] present in test data point [True]
# 238 Text feature [loss] present in test data point [True]
# 240 Text feature [1b] present in test data point [True]
# 249 Text feature [motif] present in test data point [True]
# 252 Text feature [recognition] present in test data point [True]
# 256 Text feature [stability] present in test data point [True]
# 268 Text feature [described] present in test data point [True]
# 270 Text feature [lane] present in test data point [True]
# 273 Text feature [several] present in test data point [True]
# 279 Text feature [regions] present in test data point [True]
# 290 Text feature [26] present in test data point [True]
# 291 Text feature [supplementary] present in test data point [True]
# 292 Text feature [29] present in test data point [True]
# 293 Text feature [specifically] present in test data point [True]
# 297 Text feature [mutants] present in test data point [True]
# 307 Text feature [elevated] present in test data point [True]
# 308 Text feature [interact] present in test data point [True]
# 316 Text feature [cases] present in test data point [True]
# 317 Text feature [substrate] present in test data point [True]
# 324 Text feature [activity] present in test data point [True]
# 326 Text feature [12] present in test data point [True]
# 328 Text feature [4a] present in test data point [True]
# 339 Text feature [plates] present in test data point [True]
# 342 Text feature [hours] present in test data point [True]
# 348 Text feature [lower] present in test data point [True]
# 349 Text feature [staining] present in test data point [True]
# 352 Text feature [among] present in test data point [True]
# 353 Text feature [contribute] present in test data point [True]
# 354 Text feature [reporter] present in test data point [True]
# 358 Text feature [blue] present in test data point [True]
# 366 Text feature [red] present in test data point [True]
# 371 Text feature [antibody] present in test data point [True]
# 372 Text feature [rna] present in test data point [True]
# 374 Text feature [according] present in test data point [True]
# 386 Text feature [affected] present in test data point [True]
# 390 Text feature [various] present in test data point [True]
# 393 Text feature [least] present in test data point [True]
# 395 Text feature [reduced] present in test data point [True]
# 396 Text feature [3b] present in test data point [True]
# 401 Text feature [observed] present in test data point [True]
# 402 Text feature [suggest] present in test data point [True]
# 407 Text feature [transfection] present in test data point [True]
# 408 Text feature [keap1] present in test data point [True]
# 414 Text feature [determine] present in test data point [True]
# 415 Text feature [function] present in test data point [True]
# 422 Text feature [bind] present in test data point [True]
# 430 Text feature [transactivation] present in test data point [True]
# 434 Text feature [double] present in test data point [True]
# 435 Text feature [isolated] present in test data point [True]
# 436 Text feature [analysis] present in test data point [True]
# 438 Text feature [alterations] present in test data point [True]
# 439 Text feature [anti] present in test data point [True]
# 446 Text feature [plasmid] present in test data point [True]
# 447 Text feature [pattern] present in test data point [True]
# 454 Text feature [normal] present in test data point [True]
# 456 Text feature [levels] present in test data point [True]
# 458 Text feature [similarly] present in test data point [True]
# 462 Text feature [based] present in test data point [True]
# 467 Text feature [activated] present in test data point [True]
# 469 Text feature [led] present in test data point [True]
# 470 Text feature [complex] present in test data point [True]
# 477 Text feature [including] present in test data point [True]
# 479 Text feature [detected] present in test data point [True]
# 481 Text feature [dna] present in test data point [True]
# 483 Text feature [2a] present in test data point [True]
# 485 Text feature [level] present in test data point [True]
# 491 Text feature [lysates] present in test data point [True]
# 492 Text feature [wt] present in test data point [True]
# 493 Text feature [flag] present in test data point [True]
# 496 Text feature [locus] present in test data point [True]
# Out of the top  500  features  100 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 10
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[2.840e-02 5.616e-01 1.000e-03 1.500e-02 1.380e-02 2.100e-03 3.729e-01
#   4.900e-03 3.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 47 Text feature [01] present in test data point [True]
# 55 Text feature [discovery] present in test data point [True]
# 79 Text feature [invitrogen] present in test data point [True]
# 82 Text feature [rate] present in test data point [True]
# 83 Text feature [mek] present in test data point [True]
# 86 Text feature [detection] present in test data point [True]
# 90 Text feature [05] present in test data point [True]
# 91 Text feature [group] present in test data point [True]
# 92 Text feature [sd] present in test data point [True]
# 105 Text feature [weeks] present in test data point [True]
# 113 Text feature [clear] present in test data point [True]
# 116 Text feature [various] present in test data point [True]
# 117 Text feature [stage] present in test data point [True]
# 118 Text feature [hotspots] present in test data point [True]
# 121 Text feature [harboring] present in test data point [True]
# 125 Text feature [molecular] present in test data point [True]
# 126 Text feature [novel] present in test data point [True]
# 127 Text feature [significance] present in test data point [True]
# 136 Text feature [features] present in test data point [True]
# 137 Text feature [acquired] present in test data point [True]
# 138 Text feature [potent] present in test data point [True]
# 139 Text feature [value] present in test data point [True]
# 143 Text feature [exons] present in test data point [True]
# 144 Text feature [treatment] present in test data point [True]
# 145 Text feature [groups] present in test data point [True]
# 146 Text feature [products] present in test data point [True]
# 148 Text feature [second] present in test data point [True]
# 150 Text feature [half] present in test data point [True]
# 157 Text feature [80] present in test data point [True]
# 160 Text feature [therapeutic] present in test data point [True]
# 161 Text feature [genes] present in test data point [True]
# 162 Text feature [months] present in test data point [True]
# 163 Text feature [rna] present in test data point [True]
# 164 Text feature [presented] present in test data point [True]
# 167 Text feature [none] present in test data point [True]
# 168 Text feature [unknown] present in test data point [True]
# 170 Text feature [part] present in test data point [True]
# 174 Text feature [screening] present in test data point [True]
# 178 Text feature [complete] present in test data point [True]
# 180 Text feature [types] present in test data point [True]
# 182 Text feature [across] present in test data point [True]
# 183 Text feature [pik3ca] present in test data point [True]
# 184 Text feature [overall] present in test data point [True]
# 185 Text feature [response] present in test data point [True]
# 187 Text feature [small] present in test data point [True]
# 188 Text feature [range] present in test data point [True]
# 189 Text feature [play] present in test data point [True]
# 190 Text feature [since] present in test data point [True]
# 192 Text feature [due] present in test data point [True]
# 193 Text feature [specimens] present in test data point [True]
# 198 Text feature [indeed] present in test data point [True]
# 199 Text feature [non] present in test data point [True]
# 200 Text feature [18] present in test data point [True]
# 202 Text feature [american] present in test data point [True]
# 203 Text feature [established] present in test data point [True]
# 204 Text feature [inhibitor] present in test data point [True]
# 206 Text feature [2007] present in test data point [True]
# 207 Text feature [rates] present in test data point [True]
# 208 Text feature [concentrations] present in test data point [True]
# 210 Text feature [induce] present in test data point [True]
# 211 Text feature [plates] present in test data point [True]
# 212 Text feature [pcr] present in test data point [True]
# 213 Text feature [therapy] present in test data point [True]
# 215 Text feature [six] present in test data point [True]
# 216 Text feature [90] present in test data point [True]
# 217 Text feature [method] present in test data point [True]
# 220 Text feature [target] present in test data point [True]
# 222 Text feature [patients] present in test data point [True]
# 226 Text feature [pattern] present in test data point [True]
# 227 Text feature [used] present in test data point [True]
# 228 Text feature [advanced] present in test data point [True]
# 229 Text feature [differentiation] present in test data point [True]
# 230 Text feature [patient] present in test data point [True]
# 232 Text feature [amplified] present in test data point [True]
# 235 Text feature [study] present in test data point [True]
# 240 Text feature [several] present in test data point [True]
# 241 Text feature [fish] present in test data point [True]
# 243 Text feature [correlation] present in test data point [True]
# 249 Text feature [tissue] present in test data point [True]
# 252 Text feature [apoptosis] present in test data point [True]
# 253 Text feature [able] present in test data point [True]
# 257 Text feature [activities] present in test data point [True]
# 258 Text feature [based] present in test data point [True]
# 260 Text feature [association] present in test data point [True]
# 261 Text feature [200] present in test data point [True]
# 263 Text feature [33] present in test data point [True]
# 264 Text feature [included] present in test data point [True]
# 265 Text feature [clinical] present in test data point [True]
# 266 Text feature [death] present in test data point [True]
# 267 Text feature [serum] present in test data point [True]
# 268 Text feature [samples] present in test data point [True]
# 269 Text feature [1996] present in test data point [True]
# 270 Text feature [greater] present in test data point [True]
# 271 Text feature [34] present in test data point [True]
# 272 Text feature [median] present in test data point [True]
# 273 Text feature [targets] present in test data point [True]
# 274 Text feature [signalling] present in test data point [True]
# 277 Text feature [concentration] present in test data point [True]
# 278 Text feature [different] present in test data point [True]
# 279 Text feature [treated] present in test data point [True]
# 280 Text feature [university] present in test data point [True]
# 281 Text feature [purified] present in test data point [True]
# 283 Text feature [seven] present in test data point [True]
# 284 Text feature [experimental] present in test data point [True]
# 285 Text feature [defined] present in test data point [True]
# 287 Text feature [38] present in test data point [True]
# 288 Text feature [number] present in test data point [True]
# 291 Text feature [testing] present in test data point [True]
# 292 Text feature [finding] present in test data point [True]
# 293 Text feature [many] present in test data point [True]
# 294 Text feature [clones] present in test data point [True]
# 295 Text feature [10] present in test data point [True]
# 296 Text feature [p21] present in test data point [True]
# 297 Text feature [end] present in test data point [True]
# 298 Text feature [confer] present in test data point [True]
# 299 Text feature [author] present in test data point [True]
# 300 Text feature [potential] present in test data point [True]
# 301 Text feature [line] present in test data point [True]
# 302 Text feature [cases] present in test data point [True]
# 303 Text feature [resistant] present in test data point [True]
# 304 Text feature [criteria] present in test data point [True]
# 305 Text feature [mg] present in test data point [True]
# 306 Text feature [biological] present in test data point [True]
# 309 Text feature [case] present in test data point [True]
# 310 Text feature [studies] present in test data point [True]
# 311 Text feature [approach] present in test data point [True]
# 314 Text feature [pocket] present in test data point [True]
# 317 Text feature [lower] present in test data point [True]
# 318 Text feature [54] present in test data point [True]
# 320 Text feature [generation] present in test data point [True]
# 321 Text feature [47] present in test data point [True]
# 322 Text feature [100] present in test data point [True]
# 323 Text feature [hotspot] present in test data point [True]
# 325 Text feature [seen] present in test data point [True]
# 327 Text feature [syndrome] present in test data point [True]
# 328 Text feature [events] present in test data point [True]
# 329 Text feature [15] present in test data point [True]
# 331 Text feature [significantly] present in test data point [True]
# 332 Text feature [first] present in test data point [True]
# 334 Text feature [resistance] present in test data point [True]
# 336 Text feature [isolated] present in test data point [True]
# 337 Text feature [2004] present in test data point [True]
# 340 Text feature [plasmid] present in test data point [True]
# 341 Text feature [www] present in test data point [True]
# 343 Text feature [selected] present in test data point [True]
# 344 Text feature [manuscript] present in test data point [True]
# 345 Text feature [2008] present in test data point [True]
# 346 Text feature [tissues] present in test data point [True]
# 348 Text feature [another] present in test data point [True]
# 349 Text feature [given] present in test data point [True]
# 350 Text feature [large] present in test data point [True]
# 351 Text feature [30] present in test data point [True]
# 353 Text feature [gap] present in test data point [True]
# 354 Text feature [eight] present in test data point [True]
# 356 Text feature [relatively] present in test data point [True]
# 357 Text feature [moreover] present in test data point [True]
# 358 Text feature [previous] present in test data point [True]
# 359 Text feature [considered] present in test data point [True]
# 360 Text feature [use] present in test data point [True]
# 363 Text feature [regulatory] present in test data point [True]
# 366 Text feature [lymphoma] present in test data point [True]
# 367 Text feature [major] present in test data point [True]
# 368 Text feature [ng] present in test data point [True]
# 369 Text feature [multiple] present in test data point [True]
# 370 Text feature [exhibited] present in test data point [True]
# 371 Text feature [cdk4] present in test data point [True]
# 372 Text feature [tumour] present in test data point [True]
# 373 Text feature [forms] present in test data point [True]
# 374 Text feature [would] present in test data point [True]
# 375 Text feature [unique] present in test data point [True]
# 376 Text feature [still] present in test data point [True]
# 378 Text feature [known] present in test data point [True]
# 379 Text feature [1997] present in test data point [True]
# 380 Text feature [figures] present in test data point [True]
# 381 Text feature [performed] present in test data point [True]
# 382 Text feature [days] present in test data point [True]
# 386 Text feature [d1] present in test data point [True]
# 387 Text feature [confirmed] present in test data point [True]
# 388 Text feature [materials] present in test data point [True]
# 389 Text feature [kras] present in test data point [True]
# 390 Text feature [primary] present in test data point [True]
# 391 Text feature [common] present in test data point [True]
# 392 Text feature [low] present in test data point [True]
# 393 Text feature [secondary] present in test data point [True]
# 394 Text feature [ml] present in test data point [True]
# 395 Text feature [recently] present in test data point [True]
# 396 Text feature [oncogenic] present in test data point [True]
# 397 Text feature [time] present in test data point [True]
# 398 Text feature [primers] present in test data point [True]
# 400 Text feature [27] present in test data point [True]
# 402 Text feature [carcinoma] present in test data point [True]
# 403 Text feature [double] present in test data point [True]
# 404 Text feature [enzyme] present in test data point [True]
# 405 Text feature [mapk] present in test data point [True]
# 406 Text feature [important] present in test data point [True]
# 407 Text feature [mutagenesis] present in test data point [True]
# 408 Text feature [ii] present in test data point [True]
# 410 Text feature [al] present in test data point [True]
# 411 Text feature [using] present in test data point [True]
# 412 Text feature [discussion] present in test data point [True]
# 413 Text feature [point] present in test data point [True]
# 414 Text feature [12] present in test data point [True]
# 415 Text feature [containing] present in test data point [True]
# 416 Text feature [sequencing] present in test data point [True]
# 419 Text feature [nm] present in test data point [True]
# 420 Text feature [carrying] present in test data point [True]
# 421 Text feature [chromosome] present in test data point [True]
# 422 Text feature [models] present in test data point [True]
# 423 Text feature [et] present in test data point [True]
# 424 Text feature [shows] present in test data point [True]
# 425 Text feature [constitutively] present in test data point [True]
# 426 Text feature [single] present in test data point [True]
# 427 Text feature [molecule] present in test data point [True]
# 428 Text feature [particular] present in test data point [True]
# 430 Text feature [applied] present in test data point [True]
# 431 Text feature [cohort] present in test data point [True]
# 432 Text feature [research] present in test data point [True]
# 433 Text feature [23] present in test data point [True]
# 434 Text feature [biochemical] present in test data point [True]
# 435 Text feature [mutated] present in test data point [True]
# 436 Text feature [36] present in test data point [True]
# 437 Text feature [antibody] present in test data point [True]
# 438 Text feature [p53] present in test data point [True]
# 440 Text feature [inhibitors] present in test data point [True]
# 441 Text feature [14] present in test data point [True]
# 442 Text feature [braf] present in test data point [True]
# 443 Text feature [significant] present in test data point [True]
# 444 Text feature [plasma] present in test data point [True]
# 446 Text feature [myc] present in test data point [True]
# 447 Text feature [4b] present in test data point [True]
# 448 Text feature [60] present in test data point [True]
# 449 Text feature [terminus] present in test data point [True]
# 451 Text feature [expected] present in test data point [True]
# 452 Text feature [allele] present in test data point [True]
# 453 Text feature [average] present in test data point [True]
# 454 Text feature [supplemental] present in test data point [True]
# 455 Text feature [often] present in test data point [True]
# 456 Text feature [effects] present in test data point [True]
# 458 Text feature [model] present in test data point [True]
# 459 Text feature [status] present in test data point [True]
# 461 Text feature [highly] present in test data point [True]
# 462 Text feature [set] present in test data point [True]
# 463 Text feature [28] present in test data point [True]
# 464 Text feature [contact] present in test data point [True]
# 465 Text feature [gene] present in test data point [True]
# 466 Text feature [methods] present in test data point [True]
# 468 Text feature [clinically] present in test data point [True]
# 470 Text feature [new] present in test data point [True]
# 473 Text feature [stable] present in test data point [True]
# 475 Text feature [basis] present in test data point [True]
# 476 Text feature [life] present in test data point [True]
# 477 Text feature [31] present in test data point [True]
# 478 Text feature [lesions] present in test data point [True]
# 479 Text feature [org] present in test data point [True]
# 480 Text feature [times] present in test data point [True]
# 481 Text feature [chemotherapy] present in test data point [True]
# 483 Text feature [active] present in test data point [True]
# 484 Text feature [go] present in test data point [True]
# 485 Text feature [inactive] present in test data point [True]
# 486 Text feature [population] present in test data point [True]
# 487 Text feature [assay] present in test data point [True]
# 489 Text feature [analyses] present in test data point [True]
# 490 Text feature [sequences] present in test data point [True]
# 491 Text feature [de] present in test data point [True]
# 493 Text feature [including] present in test data point [True]
# 495 Text feature [tumours] present in test data point [True]
# 496 Text feature [kinase] present in test data point [True]
# 497 Text feature [age] present in test data point [True]
# Out of the top  500  features  268 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.1241258988099483
# for C = 0.0001
# Log Loss : 1.058548411217028
# for C = 0.001
# Log Loss : 1.063254196833299
# for C = 0.01
# Log Loss : 1.2546585486054789
# for C = 0.1
# Log Loss : 1.6483809816941015
# for C = 1
# Log Loss : 1.8163853197315059
# for C = 10
# Log Loss : 1.8163853872146378
# for C = 100
# Log Loss : 1.81638553703364
# For values of best alpha =  0.0001 The train log loss is: 0.6636344911252616
# For values of best alpha =  0.0001 The cross validation log loss is: 1.058548411217028
# For values of best alpha =  0.0001 The test log loss is: 1.1180137167614193

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.058548411217028
# Number of mis-classified points : 0.3308270676691729
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0806 0.0763 0.0236 0.6791 0.0229 0.0502 0.058  0.003  0.0062]]
# Actual Class : 4
# --------------------------------------------------
# 54 Text feature [high] present in test data point [True]
# 60 Text feature [show] present in test data point [True]
# 61 Text feature [low] present in test data point [True]
# 62 Text feature [lines] present in test data point [True]
# 129 Text feature [changes] present in test data point [True]
# 130 Text feature [missense] present in test data point [True]
# 132 Text feature [suggesting] present in test data point [True]
# 133 Text feature [proteins] present in test data point [True]
# 136 Text feature [protein] present in test data point [True]
# 138 Text feature [mice] present in test data point [True]
# 139 Text feature [express] present in test data point [True]
# 140 Text feature [regions] present in test data point [True]
# 142 Text feature [process] present in test data point [True]
# 146 Text feature [mm] present in test data point [True]
# 147 Text feature [primary] present in test data point [True]
# 151 Text feature [elevated] present in test data point [True]
# 153 Text feature [induced] present in test data point [True]
# 155 Text feature [due] present in test data point [True]
# 159 Text feature [1b] present in test data point [True]
# 163 Text feature [specifically] present in test data point [True]
# 171 Text feature [motif] present in test data point [True]
# 175 Text feature [29] present in test data point [True]
# 176 Text feature [caused] present in test data point [True]
# 178 Text feature [several] present in test data point [True]
# 179 Text feature [recognition] present in test data point [True]
# 181 Text feature [deletion] present in test data point [True]
# 183 Text feature [family] present in test data point [True]
# 184 Text feature [provided] present in test data point [True]
# 186 Text feature [12] present in test data point [True]
# 187 Text feature [transfected] present in test data point [True]
# 188 Text feature [among] present in test data point [True]
# 196 Text feature [indicate] present in test data point [True]
# 197 Text feature [dominant] present in test data point [True]
# 199 Text feature [observed] present in test data point [True]
# 202 Text feature [washed] present in test data point [True]
# 204 Text feature [mutants] present in test data point [True]
# 207 Text feature [tagged] present in test data point [True]
# 209 Text feature [hours] present in test data point [True]
# 212 Text feature [endogenous] present in test data point [True]
# 213 Text feature [described] present in test data point [True]
# 216 Text feature [blue] present in test data point [True]
# 218 Text feature [26] present in test data point [True]
# 222 Text feature [various] present in test data point [True]
# 223 Text feature [antibodies] present in test data point [True]
# 230 Text feature [stability] present in test data point [True]
# 233 Text feature [red] present in test data point [True]
# 332 Text feature [plates] present in test data point [True]
# 334 Text feature [degradation] present in test data point [True]
# 339 Text feature [activity] present in test data point [True]
# 341 Text feature [decreased] present in test data point [True]
# 344 Text feature [activated] present in test data point [True]
# 346 Text feature [isolated] present in test data point [True]
# 347 Text feature [lower] present in test data point [True]
# 348 Text feature [rna] present in test data point [True]
# 349 Text feature [cases] present in test data point [True]
# 352 Text feature [according] present in test data point [True]
# 354 Text feature [reporter] present in test data point [True]
# 357 Text feature [null] present in test data point [True]
# 360 Text feature [wt] present in test data point [True]
# 361 Text feature [suggest] present in test data point [True]
# 369 Text feature [supplementary] present in test data point [True]
# 373 Text feature [double] present in test data point [True]
# 374 Text feature [analysis] present in test data point [True]
# 381 Text feature [applied] present in test data point [True]
# 384 Text feature [led] present in test data point [True]
# 387 Text feature [least] present in test data point [True]
# 388 Text feature [2a] present in test data point [True]
# 389 Text feature [heterozygous] present in test data point [True]
# 393 Text feature [including] present in test data point [True]
# 402 Text feature [transactivation] present in test data point [True]
# 405 Text feature [3b] present in test data point [True]
# 406 Text feature [amino] present in test data point [True]
# 409 Text feature [interact] present in test data point [True]
# 413 Text feature [substrate] present in test data point [True]
# 421 Text feature [rate] present in test data point [True]
# 423 Text feature [determine] present in test data point [True]
# 426 Text feature [ref] present in test data point [True]
# 429 Text feature [plasmid] present in test data point [True]
# 432 Text feature [observation] present in test data point [True]
# 441 Text feature [encoding] present in test data point [True]
# 444 Text feature [based] present in test data point [True]
# 446 Text feature [bind] present in test data point [True]
# 449 Text feature [possibility] present in test data point [True]
# 451 Text feature [locus] present in test data point [True]
# 458 Text feature [complex] present in test data point [True]
# 459 Text feature [15] present in test data point [True]
# 460 Text feature [significantly] present in test data point [True]
# 461 Text feature [methods] present in test data point [True]
# 462 Text feature [loss] present in test data point [True]
# 464 Text feature [lane] present in test data point [True]
# 467 Text feature [similarly] present in test data point [True]
# 469 Text feature [cancers] present in test data point [True]
# 470 Text feature [enhanced] present in test data point [True]
# 472 Text feature [4a] present in test data point [True]
# 474 Text feature [average] present in test data point [True]
# 475 Text feature [reduced] present in test data point [True]
# 476 Text feature [shown] present in test data point [True]
# 481 Text feature [flag] present in test data point [True]
# 482 Text feature [cellular] present in test data point [True]
# 485 Text feature [standard] present in test data point [True]
# 490 Text feature [staining] present in test data point [True]
# 491 Text feature [transfection] present in test data point [True]
# 493 Text feature [two] present in test data point [True]
# 494 Text feature [containing] present in test data point [True]
# 496 Text feature [adenocarcinoma] present in test data point [True]
# 499 Text feature [located] present in test data point [True]
# Out of the top  500  features  106 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 10
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0962 0.6468 0.0079 0.053  0.0411 0.0132 0.1308 0.0096 0.0012]]
# Actual Class : 7
# --------------------------------------------------
# 62 Text feature [discovery] present in test data point [True]
# 64 Text feature [05] present in test data point [True]
# 65 Text feature [mek] present in test data point [True]
# 66 Text feature [group] present in test data point [True]
# 68 Text feature [rate] present in test data point [True]
# 70 Text feature [01] present in test data point [True]
# 73 Text feature [stage] present in test data point [True]
# 74 Text feature [various] present in test data point [True]
# 75 Text feature [sd] present in test data point [True]
# 76 Text feature [detection] present in test data point [True]
# 77 Text feature [novel] present in test data point [True]
# 79 Text feature [groups] present in test data point [True]
# 80 Text feature [significance] present in test data point [True]
# 81 Text feature [weeks] present in test data point [True]
# 118 Text feature [invitrogen] present in test data point [True]
# 119 Text feature [exons] present in test data point [True]
# 124 Text feature [molecular] present in test data point [True]
# 125 Text feature [products] present in test data point [True]
# 127 Text feature [clear] present in test data point [True]
# 128 Text feature [none] present in test data point [True]
# 130 Text feature [testing] present in test data point [True]
# 136 Text feature [harboring] present in test data point [True]
# 137 Text feature [american] present in test data point [True]
# 138 Text feature [second] present in test data point [True]
# 139 Text feature [due] present in test data point [True]
# 141 Text feature [18] present in test data point [True]
# 142 Text feature [part] present in test data point [True]
# 143 Text feature [presented] present in test data point [True]
# 144 Text feature [play] present in test data point [True]
# 145 Text feature [types] present in test data point [True]
# 146 Text feature [80] present in test data point [True]
# 147 Text feature [death] present in test data point [True]
# 149 Text feature [half] present in test data point [True]
# 150 Text feature [across] present in test data point [True]
# 151 Text feature [range] present in test data point [True]
# 152 Text feature [treatment] present in test data point [True]
# 153 Text feature [amplified] present in test data point [True]
# 155 Text feature [used] present in test data point [True]
# 156 Text feature [established] present in test data point [True]
# 157 Text feature [value] present in test data point [True]
# 158 Text feature [several] present in test data point [True]
# 160 Text feature [since] present in test data point [True]
# 161 Text feature [unknown] present in test data point [True]
# 162 Text feature [study] present in test data point [True]
# 163 Text feature [34] present in test data point [True]
# 164 Text feature [screening] present in test data point [True]
# 165 Text feature [genes] present in test data point [True]
# 166 Text feature [samples] present in test data point [True]
# 167 Text feature [therapeutic] present in test data point [True]
# 168 Text feature [able] present in test data point [True]
# 169 Text feature [indeed] present in test data point [True]
# 170 Text feature [overall] present in test data point [True]
# 171 Text feature [purified] present in test data point [True]
# 174 Text feature [potent] present in test data point [True]
# 175 Text feature [months] present in test data point [True]
# 176 Text feature [small] present in test data point [True]
# 179 Text feature [seven] present in test data point [True]
# 180 Text feature [method] present in test data point [True]
# 181 Text feature [acquired] present in test data point [True]
# 182 Text feature [tissues] present in test data point [True]
# 189 Text feature [pcr] present in test data point [True]
# 190 Text feature [hotspots] present in test data point [True]
# 191 Text feature [pik3ca] present in test data point [True]
# 192 Text feature [rna] present in test data point [True]
# 193 Text feature [complete] present in test data point [True]
# 195 Text feature [experimental] present in test data point [True]
# 196 Text feature [induce] present in test data point [True]
# 197 Text feature [eight] present in test data point [True]
# 198 Text feature [university] present in test data point [True]
# 199 Text feature [lower] present in test data point [True]
# 201 Text feature [differentiation] present in test data point [True]
# 202 Text feature [non] present in test data point [True]
# 203 Text feature [activities] present in test data point [True]
# 204 Text feature [studies] present in test data point [True]
# 205 Text feature [target] present in test data point [True]
# 206 Text feature [specimens] present in test data point [True]
# 208 Text feature [many] present in test data point [True]
# 209 Text feature [based] present in test data point [True]
# 210 Text feature [2008] present in test data point [True]
# 211 Text feature [concentrations] present in test data point [True]
# 212 Text feature [pattern] present in test data point [True]
# 213 Text feature [plates] present in test data point [True]
# 214 Text feature [plasmid] present in test data point [True]
# 215 Text feature [patients] present in test data point [True]
# 216 Text feature [included] present in test data point [True]
# 260 Text feature [finding] present in test data point [True]
# 261 Text feature [features] present in test data point [True]
# 262 Text feature [rates] present in test data point [True]
# 264 Text feature [inhibitor] present in test data point [True]
# 265 Text feature [tissue] present in test data point [True]
# 266 Text feature [potential] present in test data point [True]
# 268 Text feature [selected] present in test data point [True]
# 269 Text feature [another] present in test data point [True]
# 271 Text feature [clones] present in test data point [True]
# 272 Text feature [syndrome] present in test data point [True]
# 273 Text feature [100] present in test data point [True]
# 274 Text feature [correlation] present in test data point [True]
# 275 Text feature [plasma] present in test data point [True]
# 276 Text feature [point] present in test data point [True]
# 277 Text feature [200] present in test data point [True]
# 279 Text feature [biological] present in test data point [True]
# 280 Text feature [six] present in test data point [True]
# 281 Text feature [fish] present in test data point [True]
# 282 Text feature [signalling] present in test data point [True]
# 283 Text feature [38] present in test data point [True]
# 285 Text feature [different] present in test data point [True]
# 286 Text feature [events] present in test data point [True]
# 287 Text feature [median] present in test data point [True]
# 288 Text feature [author] present in test data point [True]
# 289 Text feature [response] present in test data point [True]
# 290 Text feature [2007] present in test data point [True]
# 291 Text feature [use] present in test data point [True]
# 292 Text feature [association] present in test data point [True]
# 293 Text feature [defined] present in test data point [True]
# 295 Text feature [concentration] present in test data point [True]
# 296 Text feature [www] present in test data point [True]
# 297 Text feature [targets] present in test data point [True]
# 298 Text feature [important] present in test data point [True]
# 300 Text feature [apoptosis] present in test data point [True]
# 301 Text feature [moreover] present in test data point [True]
# 302 Text feature [lymphoma] present in test data point [True]
# 303 Text feature [15] present in test data point [True]
# 304 Text feature [model] present in test data point [True]
# 305 Text feature [antibody] present in test data point [True]
# 306 Text feature [10] present in test data point [True]
# 307 Text feature [first] present in test data point [True]
# 309 Text feature [recently] present in test data point [True]
# 310 Text feature [criteria] present in test data point [True]
# 311 Text feature [14] present in test data point [True]
# 312 Text feature [line] present in test data point [True]
# 313 Text feature [previous] present in test data point [True]
# 314 Text feature [serum] present in test data point [True]
# 315 Text feature [large] present in test data point [True]
# 316 Text feature [33] present in test data point [True]
# 317 Text feature [would] present in test data point [True]
# 318 Text feature [cancer] present in test data point [True]
# 319 Text feature [patient] present in test data point [True]
# 320 Text feature [significantly] present in test data point [True]
# 321 Text feature [generation] present in test data point [True]
# 323 Text feature [90] present in test data point [True]
# 324 Text feature [resistant] present in test data point [True]
# 325 Text feature [double] present in test data point [True]
# 326 Text feature [status] present in test data point [True]
# 327 Text feature [considered] present in test data point [True]
# 328 Text feature [54] present in test data point [True]
# 329 Text feature [tumour] present in test data point [True]
# 330 Text feature [therapy] present in test data point [True]
# 331 Text feature [1996] present in test data point [True]
# 332 Text feature [models] present in test data point [True]
# 334 Text feature [materials] present in test data point [True]
# 335 Text feature [gap] present in test data point [True]
# 337 Text feature [applied] present in test data point [True]
# 339 Text feature [approach] present in test data point [True]
# 343 Text feature [number] present in test data point [True]
# 344 Text feature [research] present in test data point [True]
# 345 Text feature [inhibitors] present in test data point [True]
# 346 Text feature [enzyme] present in test data point [True]
# 347 Text feature [exon] present in test data point [True]
# 348 Text feature [36] present in test data point [True]
# 349 Text feature [given] present in test data point [True]
# 351 Text feature [unique] present in test data point [True]
# 352 Text feature [assay] present in test data point [True]
# 353 Text feature [biochemical] present in test data point [True]
# 357 Text feature [2004] present in test data point [True]
# 360 Text feature [manuscript] present in test data point [True]
# 361 Text feature [advanced] present in test data point [True]
# 362 Text feature [relatively] present in test data point [True]
# 363 Text feature [27] present in test data point [True]
# 364 Text feature [performed] present in test data point [True]
# 365 Text feature [30] present in test data point [True]
# 366 Text feature [regulatory] present in test data point [True]
# 367 Text feature [mutagenesis] present in test data point [True]
# 368 Text feature [2003] present in test data point [True]
# 369 Text feature [containing] present in test data point [True]
# 370 Text feature [proliferation] present in test data point [True]
# 371 Text feature [org] present in test data point [True]
# 372 Text feature [allele] present in test data point [True]
# 373 Text feature [end] present in test data point [True]
# 374 Text feature [primers] present in test data point [True]
# 375 Text feature [1997] present in test data point [True]
# 376 Text feature [cdk4] present in test data point [True]
# 377 Text feature [population] present in test data point [True]
# 378 Text feature [carcinoma] present in test data point [True]
# 380 Text feature [47] present in test data point [True]
# 381 Text feature [basis] present in test data point [True]
# 382 Text feature [greater] present in test data point [True]
# 383 Text feature [2005] present in test data point [True]
# 384 Text feature [indicated] present in test data point [True]
# 385 Text feature [expected] present in test data point [True]
# 386 Text feature [al] present in test data point [True]
# 387 Text feature [braf] present in test data point [True]
# 388 Text feature [buffer] present in test data point [True]
# 389 Text feature [levels] present in test data point [True]
# 390 Text feature [ii] present in test data point [True]
# 391 Text feature [increase] present in test data point [True]
# 392 Text feature [revealed] present in test data point [True]
# 393 Text feature [provide] present in test data point [True]
# 394 Text feature [et] present in test data point [True]
# 395 Text feature [p53] present in test data point [True]
# 396 Text feature [distribution] present in test data point [True]
# 397 Text feature [single] present in test data point [True]
# 398 Text feature [case] present in test data point [True]
# 399 Text feature [clinical] present in test data point [True]
# 400 Text feature [shows] present in test data point [True]
# 402 Text feature [p21] present in test data point [True]
# 403 Text feature [multiple] present in test data point [True]
# 405 Text feature [low] present in test data point [True]
# 406 Text feature [discussion] present in test data point [True]
# 407 Text feature [terminus] present in test data point [True]
# 408 Text feature [1998] present in test data point [True]
# 409 Text feature [kras] present in test data point [True]
# 410 Text feature [forms] present in test data point [True]
# 411 Text feature [constitutively] present in test data point [True]
# 412 Text feature [31] present in test data point [True]
# 413 Text feature [involved] present in test data point [True]
# 416 Text feature [effects] present in test data point [True]
# 417 Text feature [carrying] present in test data point [True]
# 418 Text feature [mutated] present in test data point [True]
# 419 Text feature [23] present in test data point [True]
# 420 Text feature [set] present in test data point [True]
# 421 Text feature [indicate] present in test data point [True]
# 423 Text feature [major] present in test data point [True]
# 424 Text feature [mammalian] present in test data point [True]
# 425 Text feature [60] present in test data point [True]
# 426 Text feature [ng] present in test data point [True]
# 427 Text feature [using] present in test data point [True]
# 428 Text feature [times] present in test data point [True]
# 429 Text feature [acid] present in test data point [True]
# 430 Text feature [highly] present in test data point [True]
# 431 Text feature [amino] present in test data point [True]
# 432 Text feature [secondary] present in test data point [True]
# 433 Text feature [however] present in test data point [True]
# 434 Text feature [database] present in test data point [True]
# 435 Text feature [days] present in test data point [True]
# 436 Text feature [findings] present in test data point [True]
# 437 Text feature [inhibit] present in test data point [True]
# 438 Text feature [d1] present in test data point [True]
# 439 Text feature [contact] present in test data point [True]
# 440 Text feature [known] present in test data point [True]
# 441 Text feature [confer] present in test data point [True]
# 442 Text feature [seen] present in test data point [True]
# 443 Text feature [active] present in test data point [True]
# 444 Text feature [current] present in test data point [True]
# 445 Text feature [oncogenic] present in test data point [True]
# 446 Text feature [stable] present in test data point [True]
# 447 Text feature [respectively] present in test data point [True]
# 448 Text feature [higher] present in test data point [True]
# 449 Text feature [system] present in test data point [True]
# 450 Text feature [often] present in test data point [True]
# 452 Text feature [next] present in test data point [True]
# 453 Text feature [resistance] present in test data point [True]
# 454 Text feature [isolated] present in test data point [True]
# 455 Text feature [treated] present in test data point [True]
# 456 Text feature [26] present in test data point [True]
# 457 Text feature [characterized] present in test data point [True]
# 459 Text feature [sds] present in test data point [True]
# 460 Text feature [phosphatase] present in test data point [True]
# 461 Text feature [17] present in test data point [True]
# 462 Text feature [molecule] present in test data point [True]
# 463 Text feature [significant] present in test data point [True]
# 465 Text feature [particular] present in test data point [True]
# 466 Text feature [specificity] present in test data point [True]
# 469 Text feature [primary] present in test data point [True]
# 470 Text feature [according] present in test data point [True]
# 471 Text feature [exhibited] present in test data point [True]
# 472 Text feature [methods] present in test data point [True]
# 473 Text feature [ml] present in test data point [True]
# 474 Text feature [time] present in test data point [True]
# 475 Text feature [one] present in test data point [True]
# 476 Text feature [nm] present in test data point [True]
# 477 Text feature [membrane] present in test data point [True]
# 478 Text feature [also] present in test data point [True]
# 480 Text feature [subset] present in test data point [True]
# 481 Text feature [dna] present in test data point [True]
# 482 Text feature [19] present in test data point [True]
# 483 Text feature [analyses] present in test data point [True]
# 485 Text feature [cohort] present in test data point [True]
# 487 Text feature [directed] present in test data point [True]
# 488 Text feature [helix] present in test data point [True]
# 489 Text feature [promote] present in test data point [True]
# 490 Text feature [12] present in test data point [True]
# 492 Text feature [regulation] present in test data point [True]
# 494 Text feature [site] present in test data point [True]
# 495 Text feature [vitro] present in test data point [True]
# 496 Text feature [carried] present in test data point [True]
# 497 Text feature [development] present in test data point [True]
# 498 Text feature [still] present in test data point [True]
# Out of the top  500  features  287 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.1988751929408257
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.2159819149847786
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.1853863512053227
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.2125465870848036
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.170757976790899
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.2055095324822058
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.1665916873715692
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.203872292138557
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.167560220807986
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.202650210465926
# For values of best estimator =  1000 The train log loss is: 0.8624578825732296
# For values of best estimator =  1000 The cross validation log loss is: 1.166591687371569
# For values of best estimator =  1000 The test log loss is: 1.188837317962295

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1665916873715692
# Number of mis-classified points : 0.3966165413533835
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.1821 0.0987 0.017  0.3689 0.0678 0.056  0.1897 0.0085 0.0112]]
# Actual Class : 4
# --------------------------------------------------
# 3 Text feature [activated] present in test data point [True]
# 5 Text feature [activation] present in test data point [True]
# 6 Text feature [function] present in test data point [True]
# 8 Text feature [inhibitors] present in test data point [True]
# 9 Text feature [treatment] present in test data point [True]
# 10 Text feature [inhibitor] present in test data point [True]
# 11 Text feature [loss] present in test data point [True]
# 12 Text feature [missense] present in test data point [True]
# 14 Text feature [constitutive] present in test data point [True]
# 15 Text feature [treated] present in test data point [True]
# 18 Text feature [protein] present in test data point [True]
# 21 Text feature [constitutively] present in test data point [True]
# 22 Text feature [growth] present in test data point [True]
# 23 Text feature [cells] present in test data point [True]
# 29 Text feature [inhibition] present in test data point [True]
# 30 Text feature [activate] present in test data point [True]
# 31 Text feature [drug] present in test data point [True]
# 32 Text feature [cell] present in test data point [True]
# 39 Text feature [therapeutic] present in test data point [True]
# 49 Text feature [patients] present in test data point [True]
# 50 Text feature [stability] present in test data point [True]
# 53 Text feature [expression] present in test data point [True]
# 59 Text feature [response] present in test data point [True]
# 62 Text feature [proteins] present in test data point [True]
# 67 Text feature [resistance] present in test data point [True]
# 74 Text feature [assays] present in test data point [True]
# 75 Text feature [functions] present in test data point [True]
# 77 Text feature [dna] present in test data point [True]
# 78 Text feature [serum] present in test data point [True]
# 79 Text feature [expressing] present in test data point [True]
# 81 Text feature [lines] present in test data point [True]
# 86 Text feature [sequence] present in test data point [True]
# 88 Text feature [type] present in test data point [True]
# 93 Text feature [previously] present in test data point [True]
# 99 Text feature [interaction] present in test data point [True]
# Out of the top  100  features  35 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 25
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.2404 0.0206 0.0194 0.5614 0.0659 0.0563 0.0296 0.003  0.0036]]
# Actuall Class : 7
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 5 Text feature [activation] present in test data point [True]
# 6 Text feature [function] present in test data point [True]
# 7 Text feature [phosphorylation] present in test data point [True]
# 10 Text feature [inhibitor] present in test data point [True]
# 11 Text feature [loss] present in test data point [True]
# 12 Text feature [missense] present in test data point [True]
# 14 Text feature [constitutive] present in test data point [True]
# 16 Text feature [functional] present in test data point [True]
# 18 Text feature [protein] present in test data point [True]
# 23 Text feature [cells] present in test data point [True]
# 24 Text feature [variants] present in test data point [True]
# 25 Text feature [pathogenic] present in test data point [True]
# 26 Text feature [signaling] present in test data point [True]
# 29 Text feature [inhibition] present in test data point [True]
# 32 Text feature [cell] present in test data point [True]
# 42 Text feature [classified] present in test data point [True]
# 47 Text feature [neutral] present in test data point [True]
# 50 Text feature [stability] present in test data point [True]
# 52 Text feature [downstream] present in test data point [True]
# 53 Text feature [expression] present in test data point [True]
# 54 Text feature [inhibited] present in test data point [True]
# 62 Text feature [proteins] present in test data point [True]
# 66 Text feature [variant] present in test data point [True]
# 69 Text feature [inactivation] present in test data point [True]
# 73 Text feature [clinical] present in test data point [True]
# 74 Text feature [assays] present in test data point [True]
# 77 Text feature [dna] present in test data point [True]
# 78 Text feature [serum] present in test data point [True]
# 79 Text feature [expressing] present in test data point [True]
# 83 Text feature [affect] present in test data point [True]
# 85 Text feature [predicted] present in test data point [True]
# 86 Text feature [sequence] present in test data point [True]
# 88 Text feature [type] present in test data point [True]
# 89 Text feature [phosphorylated] present in test data point [True]
# 92 Text feature [splice] present in test data point [True]
# 93 Text feature [previously] present in test data point [True]
# 98 Text feature [information] present in test data point [True]
# 99 Text feature [interaction] present in test data point [True]
# Out of the top  100  features  40 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 2.157599683969972
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.6878634761504494
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.5521665851528843
# for n_estimators = 10 and max depth =  10
# Log Loss : 1.8665266550094355
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.7120743498593836
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.4493705432389667
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.435817308324955
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.765632161422817
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.5889350668709925
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.5255583252443894
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.368257049773497
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.7315084009239994
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.6784214004039908
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.5440035734446413
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.415358594622114
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.6704898314703855
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.7501714985666794
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.6079886487305148
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.386629818789831
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.7201565299113437
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.737128848555457
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.6055527017056603
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.3583537627490643
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.7184554001975505
# For values of best alpha =  1000 The train log loss is: 0.050574652264909925
# For values of best alpha =  1000 The cross validation log loss is: 1.3583537627490643
# For values of best alpha =  1000 The test log loss is: 1.3516805861181866

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.3583537627490643
# Number of mis-classified points : 0.518796992481203
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 1
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.0852 0.0524 0.181  0.4466 0.0433 0.0747 0.0399 0.033  0.044 ]]
# Actual Class : 4
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index =25
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[0.2056 0.0223 0.134  0.4016 0.0728 0.0984 0.0099 0.0245 0.0309]]
# Actual Class : 7
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.00
# Support vector machines : Log Loss: 1.82
# Naive Bayes : Log Loss: 1.14
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.178
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.034
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.502
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.115
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.139
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.270

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.8165072519841278
# Log loss (CV) on the stacking classifier : 1.1150717843665523
# Log loss (test) on the stacking classifier : 1.1683860118129907
# Number of missclassified point : 0.3774436090225564
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.9540533759084159
# Log loss (CV) on the VotingClassifier : 1.157950451753377
# Log loss (test) on the VotingClassifier : 1.1923035437421432
# Number of missclassified point : 0.3849624060150376
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # Performance Table :-

# %%
print()
from prettytable import PrettyTable
ptable = PrettyTable()
ptable.title = 'Model Summary with TFIDF vectorrizer'
ptable.field_names=["Model Name","Train","CV","Test","% Misclassified Points"]
ptable.add_row(["Naive Bayes","0.796","1.133","1.190","36.65"])
ptable.add_row(["KNN","0.643","0.986","1.083","35.52"])
ptable.add_row(["Logistic Regression With Class balancing","0.585","0.981","1.030","32.59"])
ptable.add_row(["Logistic Regression Without Class balancing","0.573","1.004","1.048","32.70"])
ptable.add_row(["Linear SVM","0.663","1.058","1.118","33.08"])
ptable.add_row(["Random Forest Classifier With One hot Encoding","0.862","1.166","1.188","39.66"])
ptable.add_row(["Random Forest Classifier With Response Coding","0.050","1.358","1.351","51.87"])
ptable.add_row(["Stack Models:LR+NB+SVM","0.816","1.115","1.0168","37.74"])
ptable.add_row(["Maximum Voting classifier","0.954","1.157","1.192","38.49"])
print(ptable)
print()
# Out:
# +------------------------------------------------+-------+-------+--------+------------------------+
# |                   Model Name                   | Train |   CV  |  Test  | % Misclassified Points |
# +------------------------------------------------+-------+-------+--------+------------------------+
# |                  Naive Bayes                   | 0.796 | 1.133 | 1.190  |         36.65          |
# |                      KNN                       | 0.643 | 0.986 | 1.083  |         35.52          |
# |    Logistic Regression With Class balancing    | 0.585 | 0.981 | 1.030  |         32.59          |
# |  Logistic Regression Without Class balancing   | 0.573 | 1.004 | 1.048  |         32.70          |
# |                   Linear SVM                   | 0.663 | 1.058 | 1.118  |         33.08          |
# | Random Forest Classifier With One hot Encoding | 0.862 | 1.166 | 1.188  |         39.66          |
# | Random Forest Classifier With Response Coding  | 0.050 | 1.358 | 1.351  |         51.87          |
# |             Stack Models:LR+NB+SVM             | 0.816 | 1.115 | 1.0168 |         37.74          |
# |           Maximum Voting classifier            | 0.954 | 1.157 | 1.192  |         38.49          |
# +------------------------------------------------+-------+-------+--------+------------------------+

# %% [markdown]
# From the above performance table we can able to see that LogisticRegression with class balancing performing very well on this dataset, So we will try 3-gram , counervecorirzer with 2 gramas and some feature engineering techinique to reduce the log loss function from all the set of DATA

# %% [markdown]
# # LogisticRegression On countervectorizer 2-gram and max 2000 text data:-

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer(min_df=3)
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# one-hot encoding of variation feature.
variation_vectorizer = CountVectorizer(min_df=3)
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# one-hot encoding of Text feature.
text_vectorizer = CountVectorizer(max_features=2000,ngram_range=(1,3))
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %% [markdown]
# ## Stacking All the above onehot encoded value

# %%
# %%time
train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))
# Out:
# Wall time: 249 ms

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    #clf=LogisticRegression(class_weight='balanced', C=10, max_iter=1000,penalty='l2', solver='saga', random_state=42, n_jobs=16)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1710916312730815
# for alpha = 1e-05
# Log Loss : 1.1329701974511253
# for alpha = 0.0001
# Log Loss : 1.014168937982916
# for alpha = 0.001
# Log Loss : 1.0938714340504339
# for alpha = 0.01
# Log Loss : 1.33608550626604
# for alpha = 0.1
# Log Loss : 1.792850537539494
# for alpha = 1
# Log Loss : 1.8357326874323112
# for alpha = 10
# Log Loss : 1.8391774372290146
# for alpha = 100
# Log Loss : 1.839536694859021
# For values of best alpha =  0.0001 The train log loss is: 0.7111029402818442
# For values of best alpha =  0.0001 The cross validation log loss is: 1.014168937982916
# For values of best alpha =  0.0001 The test log loss is: 1.0398401931999508

# %% [markdown]
# # feature engineering

# %% [markdown]
# ## Tfidf with 4 gram

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = TfidfVectorizer(min_df=3)
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# one-hot encoding of variation feature.
variation_vectorizer = TfidfVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# one-hot encoding of Text feature.
text_vectorizer = TfidfVectorizer(max_features=3000,ngram_range=(1,4))
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
# %%time
train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))
# Out:
# Wall time: 349 ms

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    #clf=LogisticRegression(class_weight='balanced', C=10, max_iter=1000,penalty='l2', solver='saga', random_state=42, n_jobs=16)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.0674670053118291
# for alpha = 1e-05
# Log Loss : 1.065728776554902
# for alpha = 0.0001
# Log Loss : 0.9866633035612222
# for alpha = 0.001
# Log Loss : 1.0152948541204723
# for alpha = 0.01
# Log Loss : 1.1288208258774317
# for alpha = 0.1
# Log Loss : 1.6626442625249302
# for alpha = 1
# Log Loss : 1.810699369526316
# for alpha = 10
# Log Loss : 1.8262873635188754
# for alpha = 100
# Log Loss : 1.8279839311464454
# For values of best alpha =  0.0001 The train log loss is: 0.4342937028464589
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9866633035612222
# For values of best alpha =  0.0001 The test log loss is: 1.0639244886591426

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9866633035612222
# Number of mis-classified points : 0.31203007518796994
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# ## Predict model with gene and Text feature:-

# %%
# one-hot encoding of Gene feature.
#gene_vectorizer = TfidfVectorizer(min_df=3)
#train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
#test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
#cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# one-hot encoding of variation feature.
variation_vectorizer = TfidfVectorizer(min_df=3)
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# one-hot encoding of Text feature.
text_vectorizer = TfidfVectorizer(max_features=3000,ngram_range=(1,4))
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
# %%time
#train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
#test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
#cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_feature_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_feature_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_feature_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))
# Out:
# Wall time: 258 ms

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    #clf=LogisticRegression(class_weight='balanced', C=10, max_iter=1000,penalty='l2', solver='saga', random_state=42, n_jobs=16)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.1243006963076225
# for alpha = 1e-05
# Log Loss : 1.102135642418825
# for alpha = 0.0001
# Log Loss : 1.0270278969700295
# for alpha = 0.001
# Log Loss : 1.0767392417656596
# for alpha = 0.01
# Log Loss : 1.202863007155142
# for alpha = 0.1
# Log Loss : 1.7351214680630236
# for alpha = 1
# Log Loss : 1.8434058762300638
# for alpha = 10
# Log Loss : 1.8545866687468366
# for alpha = 100
# Log Loss : 1.8558220110190389
# For values of best alpha =  0.0001 The train log loss is: 0.7033959266090963
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0270278969700295
# For values of best alpha =  0.0001 The test log loss is: 1.105315977713609

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0270278969700295
# Number of mis-classified points : 0.37406015037593987
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # Conclusion :-

# %% [markdown]
# 1). we tried multiple things and we found that logistice regression with 4 gram is giving best result with log loss of  0.986 and 31.20 % miss clasifed point .
#
# 2). Contervectorizer with bi gram and trigram performing well than 1 gram .
#
# 3). For this problem so domain export help required to check how gene variation creating the cancer , as we saw in gene there are very much variation which cuase to be class between (1-9).
